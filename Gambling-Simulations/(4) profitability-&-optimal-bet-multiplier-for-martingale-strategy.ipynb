# %%
import random
import matplotlib
import matplotlib.pyplot as plt
import time

from matplotlib import style
style.use('ggplot')  
plt.figure(figsize = (15 , 8))
def rollDice():
  roll = random.randint(1 , 100) 
  if ( roll == 100 ):
    return False

  elif (roll <= 50):
    return False

  elif ( 51 <= roll <= 99):
    return True

def doubler_bettor(funds, initial_wager, wager_count):
  value = funds #initial value, value is how much money he has
  wager = initial_wager #initial bet amount
  global broke_count_d
  global winners_d
  w_X = [] #for plotting
  v_Y = [] #for plotting

  currentWager = 1 #counter
  previousWager = 'win' #last bet win or lose
  previousWagerAmount = initial_wager #last bet amount


  while (currentWager <= wager_count):

    if (previousWager == 'win'):        #we had won previous role 
      wager = initial_wager
      if (rollDice()):
        value = value + wager
        w_X.append(currentWager)
        v_Y.append(value)
      else:
        value = value - wager
        previousWager = 'loss'
        previousWagerAmount = wager  # wager = initial wager
        w_X.append(currentWager)
        v_Y.append(value)
        if value < 0:
          broke_count_d += 1
          break



    elif( previousWager =='loss'):      #we had lost previous roll
      wager = previousWagerAmount * 2 #new bet amount

      if ((rollDice())):               #we won this roll
        if ((value - wager)<0):
          wager = value
        
        value = value + wager
        #Now         
        previousWager = 'win'            
        w_X.append(currentWager)
        v_Y.append(value)
      
      else:                           #we lost this roll 
        if ((value - wager)<0):
          wager = value
        
        value = value - wager
        #Now
        previousWager = 'loss'
        previousWagerAmount = wager
        w_X.append(currentWager)
        v_Y.append(value)

        if (value <= 0):
          broke_count_d += 1
          break

    currentWager += 1 

  plt.plot (w_X , v_Y , 'blue')
  if (value > funds):
    winners_d += 1 



def simple_bettor(funds , initial_wager, wager_count):
  value = funds #value is how much money he has
  wager = initial_wager #initial bet amount
  global broke_count_s
  global winners_s
  w_X = [] #for plotting
  v_Y = [] #for plotting

  currentWager = 1 #counter

  while currentWager <= wager_count:
    if (rollDice()) : 
      value = value + wager
      w_X.append(currentWager)
      v_Y.append(value)
    else:
      value = value - wager
      w_X.append(currentWager)
      v_Y.append(value)
      if (value <= 0 ):
        break

    currentWager = currentWager + 1
  
  if (value>funds):
    winners_s += 1

  if (value <= 0):
    value = 'broke'
    broke_count_s += 1
  plt.plot(w_X , v_Y , 'lime' )

       

def gambler_simulation(sampleSize_input , startingFunds_input , wagerSize_input , wagerCount_input):

  x = 0 
  while(x < sampleSize_input):
    simple_bettor(startingFunds_input , wagerSize_input , wagerCount_input)
    doubler_bettor(startingFunds_input , wagerSize_input , wagerCount_input)
    x = x + 1 

  print('broke gamblers % for simple bettor: ' , (float(broke_count_s)/float(sampleSize))*100)
  print('broke gamblers % for doubler bettor:' , (float(broke_count_d)/float(sampleSize))*100)

  print('profiting gamblers % for simple bettor', (float(winners_s)/float(sampleSize))*100)
  print('profiting gamblers % for doubler bettor' , (float(winners_d)/float(sampleSize))*100)
  plt.axhline(0 , color = 'r')
  plt.ylabel('Gambler\'s fund Balance ')
  plt.xlabel('Number of bets (Wager Count)')
  plt.show()

sampleSize = 100
startingFunds = 10000
wagerSize = 100 
wagerCount = 1000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  2.0
# broke gamblers % for doubler bettor: 87.0
# profiting gamblers % for simple bettor 27.0
# profiting gamblers % for doubler bettor 13.0

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 100 
wagerCount = 100

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  0.0
# broke gamblers % for doubler bettor: 32.5
# profiting gamblers % for simple bettor 38.4
# profiting gamblers % for doubler bettor 62.3

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 10000
startingFunds = 10000
wagerSize = 10
wagerCount = 100

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  0.0
# broke gamblers % for doubler bettor: 4.31
# profiting gamblers % for simple bettor 38.01
# profiting gamblers % for doubler bettor 93.51

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 10
wagerCount = 1000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  0.0
# broke gamblers % for doubler bettor: 32.6
# profiting gamblers % for simple bettor 25.6
# profiting gamblers % for doubler bettor 55.900000000000006

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 100 
wagerCount = 1000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  1.3
# broke gamblers % for doubler bettor: 85.8
# profiting gamblers % for simple bettor 26.1
# profiting gamblers % for doubler bettor 14.000000000000002

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 100 
wagerCount = 10000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  91.4
# broke gamblers % for doubler bettor: 99.4
# profiting gamblers % for simple bettor 2.3
# profiting gamblers % for doubler bettor 0.6

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 10
wagerCount = 10000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  0.0
# broke gamblers % for doubler bettor: 88.2
# profiting gamblers % for simple bettor 1.4000000000000001
# profiting gamblers % for doubler bettor 11.600000000000001

# %%
style.use('ggplot')  
plt.figure(figsize = (15 , 8))

sampleSize = 1000
startingFunds = 10000
wagerSize = 100
wagerCount = 10000

broke_count_s = 0
broke_count_d = 0 
winners_s = 0 
winners_d = 0 

gambler_simulation(sampleSize , startingFunds, wagerSize , wagerCount)
# Out:
# broke gamblers % for simple bettor:  91.60000000000001
# broke gamblers % for doubler bettor: 99.3
# profiting gamblers % for simple bettor 1.0999999999999999
# profiting gamblers % for doubler bettor 0.7000000000000001

# %%
import random
import matplotlib
import matplotlib.pyplot as plt
import time



def rollDice():
  roll = random.randint(1 , 100) 
  if ( roll == 100 ):
    return False

  elif (roll <= 50):
    return False

  elif ( 51 <= roll <= 99):
    return True

def multiple_bettor(funds, initial_wager, wager_count):
  global broke_count_m
  global winners_m

  value = funds
  wager = initial_wager
  currentWager = 1 
  previousWager = 'win'
  previousWagerAmount = initial_wager #last bet amount


  while (currentWager <= wager_count):

    if (previousWager == 'win'):        #we had won previous role 
      wager = initial_wager
      if (rollDice()):
        value = value + wager
      else:
        value = value - wager
        previousWager = 'loss'
        previousWagerAmount = wager  # wager = initial wager
        if value < 0:
          broke_count_m += 1
          break



    elif( previousWager =='loss'):      #we had lost previous roll
      wager = previousWagerAmount * bet_multiplier #new bet amount

      if ((rollDice())):               #we won this roll
        if ((value - wager)<0):
          wager = value
        
        value = value + wager
        #Now         
        previousWager = 'win'            
      
      else:                           #we lost this roll 
        if ((value - wager)<0):
          wager = value
        
        value = value - wager
        #Now
        previousWager = 'loss'
        previousWagerAmount = wager

        if (value <= 0):
          broke_count_m += 1
          break

    currentWager += 1 

  if (value > funds):
    winners_m += 1 

 
broke_rate_low = 32.0 #target that we want to beat
winners_rate_high = 60.0 #target that we want to beat

x= 0 
counter = 0 
while (x<= 20):
  funds = 10000
  initial_wager = 100
  wager_count = 1000

  testSize = 10000
  currentSample = 1 

  broke_count_m = 0 
  winners_m = 0 

  bet_multiplier = random.uniform (0.5 , 2.8)
  while (currentSample <= testSize):
    multiple_bettor(funds, initial_wager, wager_count)
    currentSample += 1
  x+=1
  if ((float(broke_count_m)/float(testSize))*100< broke_rate_low  and \
        ((float(winners_m))/float(testSize))*100 > winners_rate_high):
    print('\n')
    print('codition satisfied for bet Multiplier = ', bet_multiplier)
    print('broke rate:' , (float(broke_count_m)/float(testSize))*100)
    print('profiting gamblers rate:',(float(winners_m)/float(testSize))*100 )
    print('\n') 

  else:
    pass
    print('\n')
    print('codition not satisfied for bet Multiplier = ', bet_multiplier)
    print('broke rate:' , (float(broke_count_m)/float(testSize))*100)
    print('profiting gamblers rate:',(float(winners_m)/float(testSize))*100 )
    print('\n')
# Out:
# codition not satisfied for bet Multiplier =  2.2866715110017526
# broke rate: 92.75999999999999
# profiting gamblers rate: 7.23
#
#
#
#
# codition not satisfied for bet Multiplier =  1.3102749077673872
# broke rate: 19.59
# profiting gamblers rate: 31.89
#
#
#
#
# codition not satisfied for bet Multiplier =  2.0335270719915775
# broke rate: 86.83
# profiting gamblers rate: 12.959999999999999
#
#
#
#
# codition not satisfied for bet Multiplier =  2.0231032289270807
# broke rate: 86.83
# profiting gamblers rate: 12.97
#
#
#
#
# codition not satisfied for bet Multiplier =  1.791119111165822
# broke rate: 74.99
# profiting gamblers rate: 24.38
#
#
#
#
# codition not satisfied for bet Multiplier =  2.1142641967226337
# broke rate: 89.68
# profiting gamblers rate: 10.22
#
#
#
#
# codition not satisfied for bet Multiplier =  2.1107681533324714
# broke rate: 89.62
# profiting gamblers rate: 10.32
#
#
#
#
# codition not satisfied for bet Multiplier =  1.3229432355610544
# broke rate: 21.34
# profiting gamblers rate: 33.21
#
#
#
#
# codition not satisfied for bet Multiplier =  1.4039540780925064
# broke rate: 32.73
# profiting gamblers rate: 36.980000000000004
#
#
#
#
# codition not satisfied for bet Multiplier =  2.170767392524336
# broke rate: 90.7
# profiting gamblers rate: 9.22
#
#
#
#
# codition not satisfied for bet Multiplier =  2.1863861035123913
# broke rate: 90.44
# profiting gamblers rate: 9.55
#
#
#
#
# codition not satisfied for bet Multiplier =  0.861074278407627
# broke rate: 0.27
# profiting gamblers rate: 26.32
#
#
#
#
# codition not satisfied for bet Multiplier =  2.663797306151934
# broke rate: 96.64
# profiting gamblers rate: 3.35
#
#
#
#
# codition not satisfied for bet Multiplier =  2.0228457956961954
# broke rate: 86.59
# profiting gamblers rate: 13.15
#
#
#
#
# codition not satisfied for bet Multiplier =  1.3565442353411856
# broke rate: 26.76
# profiting gamblers rate: 33.93
#
#
#
#
# codition not satisfied for bet Multiplier =  2.2152060067909676
# broke rate: 92.02
# profiting gamblers rate: 7.93
#
#
#
#
# codition not satisfied for bet Multiplier =  1.9223330327261257
# broke rate: 82.50999999999999
# profiting gamblers rate: 17.25
#
#
#
#
# codition not satisfied for bet Multiplier =  2.5651620953403644
# broke rate: 96.0
# profiting gamblers rate: 4.0
#
#
#
#
# codition not satisfied for bet Multiplier =  1.9217738320714735
# broke rate: 82.45
# profiting gamblers rate: 17.32
#
#
#
#
# codition not satisfied for bet Multiplier =  2.3915517863867786
# broke rate: 94.36
# profiting gamblers rate: 5.64
#
#
#
#
# codition not satisfied for bet Multiplier =  2.231329689339208
# broke rate: 92.08
# profiting gamblers rate: 7.91
